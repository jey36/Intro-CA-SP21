# %% [markdown]
# # **Course Schedule — Spring 2021**

# %% [markdown]
# | **Week** | **Date**        | **Topic**                                          | **Technical Reading**                                                                                                                                             | **Critical/Cultural Reading**                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | **Tasks**                                                                                                                                                                                                                                                            | **Assignment**      |
# |:------|:-------|:----------|:------------|:---------|:--------------|:-----------|
# | Week 1   | Mon Feb 8       | Introductions                                      |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed Feb 10      | Command Line & Files, Files, Files                 | *Read [The Command Line](https://info1350.github.io/Intro-CA-SP21/01-Command-Line/01-The-Command-Line.html)                                                            | *Read and annotate [“The Yellow Wallpaper,”](https://www.nlm.nih.gov/exhibition/theliteratureofprescription/exhibitionAssets/digitalDocs/The-Yellow-Wall-Paper.pdf) Charlotte Perkins Gilman (Perusall)                                                                                                                                                                                                                                                                                                                               | *Fill out [intro survey](https://docs.google.com/forms/d/e/1FAIpQLSf_eYZhPfLZLIBY7WHrt4_UGdSGEx_UbVfn5_o4jTTtqyQViA/viewform?usp=sf_link)                                                                                                                           |                                |
# |          | Fri Feb 12      | Introduction to Python & GitHub                    | *Read [How To Use Jupyter Notebooks](https://info1350.github.io/Intro-CA-SP21/02-Python/02-How-to-Use-Jupyter-Notebooks.html)                                          |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              | *Download and install [Anaconda](https://info1350.github.io/Intro-CA-SP21/02-Python/01-Installation.html) *Make a [GitHub account](https://github.com/join) *Download [GitHub Desktop](https://desktop.github.com/) *Download [VSCode](https://code.visualstudio.com/) | HW 1 Due                       |
# | Week 2   | Mon Feb 15      | Python — Variables & Data Types                    | *Read [Variables](https://info1350.github.io/Intro-CA-SP21/02-Python/05-Variables.html), [Data Types](https://info1350.github.io/Intro-CA-SP21/02-Python/04-Data-Types.html) | *Read and annotate “Introduction,” *Data Feminism,* Catherine D’Ignazio and Lauren Klein (Perusall)                                                                                                                                                                                                                                                                                                                                                                                                                                    | *[Install Jupyter Variable Inspector](https://info1350.github.io/Intro-CA-SP21/02-Python/01-Installation#installing-variable-inspector.html)                                                                                                                                                                                                                                  |                                |
# |          | Wed Feb 17      | Python — Files, Character Encoding, String Methods | *Read [Files and Character Encoding](https://info1350.github.io/Intro-CA-SP21/Python/Files-Character-Encoding.html)                                              | *Read and annotate [“I Can Text You A Pile of Poo, But I Can’t Write My Name,”](https://modelviewculture.com/pieces/i-can-text-you-a-pile-of-poo-but-i-cant-write-my-name) Aditya Mukerjee (Perusall)                                                                                                                                                                                                                                                                                                                                   |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri Feb 19      | Python — String Methods                            | *Read [String Methods](https://info1350.github.io/Intro-CA-SP21/Python/String-Methods.html)                                                                      |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      | HW 2 Due                       |
# | Week 3   | Mon Feb 22      | Python — Conditionals & Comparisons                | *Read [Conditionals & Comparisons](https://info1350.github.io/Intro-CA-SP21/Python/Comparisons-Conditionals.html)                                                | *Read and annotate [“(Re)Humanizing Data: Digitally Navigating the Bellevue Almshouse”](http://crdh.rrchnm.org/essays/v01-10-(re)-humanizing-data/) Anelise Hanson Shrout (Perusall)                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed Feb 24      | Python — Lists & Loops                             | *Read [Lists & Loops](https://info1350.github.io/Intro-CA-SP21/Python/Lists-Loops-Part1.html)                                                                    |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri Feb 26      | Python — Lists & Loops                             | *Read [Lists & Loops](https://info1350.github.io/Intro-CA-SP21/Python/Lists-Loops-Part2.html) Part 2                                                             | *Read and annotate ["What Gets Counted Counts,"](https://data-feminism.mitpress.mit.edu/pub/h1w0nbqp/release/2) *Data Feminism*, Catherine D’Ignazio and Lauren Klein (Perusall)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |                                                                                                                                                                                                                                                                      | Homework 3 Due                 |
# | Week 4   | Mon March 1     | Python — Dictionaries, Functions                                       | *Read [Dictionaries](https://info1350.github.io/Intro-CA-SP21/Python/Dictionaries.html), [Functions](https://info1350.github.io/Intro-CA-SP21/Python/Functions.html)                                                                           | *Read and annotate ["Unicorns, Janitors, Ninjas, Wizards, and Rock Stars,"](https://data-feminism.mitpress.mit.edu/pub/2wu7aft8/release/2) *Data Feminism*, Catherine D’Ignazio and Lauren Klein (Perusall)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed March 3     | Dictionaries, Functions                                          | *Read [Dictionaries](https://info1350.github.io/Intro-CA-SP21/Python/Dictionaries.html), [Functions](https://info1350.github.io/Intro-CA-SP21/Python/Functions.html)                                                                                |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri March 5     | Object-Oriented Programming                        |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      | Homework 4 Due                 |
# | Week 5   | Mon March 8     | Python Review                                      |                                                                                                                                                                   | *Read and annotate ["The Numbers Don't Speak For Themselves"](https://data-feminism.mitpress.mit.edu/pub/czq9dfs5/release/2) *Data Feminism*, Catherine D’Ignazio and Lauren Klein (Perusall)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed March 10    | Wellness Day                                       |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Friday March 12 | Data Analysis — Pandas                             | *Read [Pandas Basics](https://info1350.github.io/Intro-CA-SP21/Data-Analysis/Pandas-Basics-Part1.html)                                                           | *Read [“Data Biographies,”](https://gijn.org/2017/03/27/data-biographies-getting-to-know-your-data/) Heather Krause                                                                                                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                                                                                      |                                |
# | Week 6   | Monday March 15 | Data Analysis — Pandas                             |                                                                                                                                                                   | *Read [“Markup Bodies: Black [Life] Studies and Slavery [Death] Studies at the Digital Crossroads”](https://read.dukeupress.edu/social-text/article-abstract/36/4%20(137)/57/137032/Markup-BodiesBlack-Life-Studies-and-Slavery-Death?redirectedFrom=fulltext) Jessica Marie Johnson (Perusall)                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed March 17    | Data Analysis — Pandas                             |                                                                                                                                                                   | *Read [“Film Dialogue from 2,000 screenplays, Broken Down by Gender and Age”,](https://pudding.cool/2017/03/film-dialogue/) Hannah Anderson and Matt Daniels *Read [Film Dialogue FAQ](https://medium.com/@matthew_daniels/faq-for-the-film-dialogue-by-gender-project-40078209f751) (Perusall)                                                                                                                                                                                                                                         |                                                                                                                                                                                                                                                                      |                                |
# |          | Friday March 19 | Data Analysis — Pandas                             |                                                                                                                                                                   | *Read Datasheets for Datasets                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                                                                                                                                                                                                                                                                      |                                |
# | Week 7   | Monday March 22 | Data Collection — Web Scraping                     |                                                                                                                                                                   | *Read [“The Largest Vocabulary in Hip-Hop,”](https://pudding.cool/projects/vocabulary/index.html) Matt Daniels *Listen to Missy Elliott’s [Under Construction](https://open.spotify.com/album/6DeU398qrJ1bLuryetSmup?si=E7KB2LAcSLyWfkTt9IONrA)                                                                                                                                                                                                                                                                            |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed March 24    | Data Collection — Web Scraping                     |                                                                                                                                                                   | *Read ["The Secretive Company That Might End Privacy as We Know It"](https://www.nytimes.com/2020/01/18/technology/clearview-privacy-facial-recognition.html) Kashmir Hill    (Perusall)                                                                                                                                                                                                                                                                                                                                                 |                                                                                                                                                                                                                                                                      |                                |
# |          | Friday March 26 | Data Collection — APIs                             |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      | **Midterm Project Due**        |
# | Week 8   | Mon March 29    | Data Collection — APIs                             |                                                                                                                                                                   | *Read [“Narrative Paths and Negotiation of Power in Birth Stories,”](https://maria-antoniak.github.io/resources/2019_cscw_birth_stories.pdf) Maria Antoniak, David Mimno, and Karen Levy     (Perusall)                                                                                                                                                                                                                                                                                                                                  |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed March 31    | Text Analysis                                      |                                                                                                                                                                   | *Read excerpts of *The House on Mango Street*                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri April 2     | Text Analysis                                      |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# | Week 9   | Mon April 5     | Text Analysis                                      |                                                                                                                                                                   | *Read [“Beyond Canonical Texts: A Computational Analysis of Fanfiction,”](https://www.aclweb.org/anthology/D16-1218.pdf) Smitha Milli and David Bamman                                                                                                                                                                                                                                                                                                                                                                      |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed April 7     | Text Analysis                                      |                                                                                                                                                                   | *Reading TBA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri April 9     | Text Analysis                                      |                                                                                                                                                                   | *Read and explore ["Introduction,"](https://iopn.library.illinois.edu/scalar/lost-in-the-city-a-exploration-of-edward-p-joness-short-fiction-/the-introduction-an-authors-note) ["A Multimedia Literary Analysis,” (Sections 1-3)](https://iopn.library.illinois.edu/scalar/lost-in-the-city-a-exploration-of-edward-p-joness-short-fiction-/lost-in-the-city---section-2?path=chapter-3-lost-in-the-city), *Lost in the City: An Exploration of Edward P. Jones's Short Fiction*, Kenton Rambsy and Peace Ossom-Williamson |                                                                                                                                                                                                                                                                      | Homework 5                     |
# | Week 10  | Mon April 12    | Text/Network Analysis                              | *Read ["Demystifying Networks"](http://journalofdigitalhumanities.org/1-1/demystifying-networks-by-scott-weingart/), Scott Weingart                              | *Watch TBA episode of Game of Thrones *Read [“Network of Thrones,”](https://www.maa.org/sites/default/files/pdf/Mathhorizons/NetworkofThrones%20%281%29.pdf) Andrew Beveridge and Jie Shan                                                                                                                                                                                                                                                                                                                                 |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed April 14    | Network Analysis                                   | *Read ["Demystifying Networks"](http://journalofdigitalhumanities.org/1-1/demystifying-networks-by-scott-weingart/), Scott Weingart                              |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri April 16    | Network Analysis                                   |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      | Homework 6 Due                 |
# | Week 11  | Mon April 19    | Mapping                                            |                                                                                                                                                                   | *Explore [Torn Apart / Separados](http://xpmethod.plaintext.in/torn-apart/volume/2/index), Manan Ahmed, Alex Gil, Moacir P. de Sá Pereira, Roopika Risam, Maira E. Álvarez, Sylvia A. Fernández, Linda Rodriguez, and Merisa Martinez *Read ['ICE Is Everywhere': Using Library Science to Map the Separation Crisis,](https://www.wired.com/story/ice-is-everywhere-using-library-science-to-map-child-separation/) Emily Dreyfuss                                                                                        |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed April 21    | Mapping                                            |                                                                                                                                                                   | *Read [“How an internet mapping glitch turned a random Kansas farm into a digital hell,”](https://splinternews.com/how-an-internet-mapping-glitch-turned-a-random-kansas-f-1793856052) Kashmir Hill                                                                                                                                                                                                                                                                                                                         |                                                                                                                                                                                                                                                                      | Homework 7 Due                 |
# |          | Fri Aril 23     | Wellness Day                                       |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# | Week 12  | Mon April 26    | Wellness Day                                       |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Wed April 28    | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   | *Reading TBA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri April 30    | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   | *Reading TBA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      |                                |
# | Week 13  | Mon May 3       | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   | *Reading TBA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      | **Final Project Proposal Due** |
# |          | Wed May 5       | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   | *Reading TBA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri May 7       | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   | *Reading TBA                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |                                                                                                                                                                                                                                                                      |                                |
# | Week 14  | Mon May 10      | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      | **Dataset Due**                |
# |          | Wed May 12      | How to Make Arguments and Tell Stories With Data   |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          | Fri May 14      | Last Day                                           |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      |                                |
# |          |                 |                                                    |                                                                                                                                                                   |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |                                                                                                                                                                                                                                                                      | **Final Project Due**          |

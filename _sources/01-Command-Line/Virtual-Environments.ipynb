# %% [markdown]
# # Virtual Environments

# %% [markdown]
# ## Create a New Environment

# %%
# !conda create --name Intro-CA-Data-Collection

# %% [markdown]
# Conda will ask if you want to proceed. Type "y" and press enter.

# %%
Proceed ([y]/n)? y

# %% [markdown]
# ## Activate Environment

# %%
# !conda activate Intro-CA-Data-Collection

# %% [markdown]
# ## Install Packages

# %%
# !conda install beautifulsoup4
# Out:
# ...
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
# \
#   - conda-forge/osx-64::certifi==2020.12.5=py37hf985489_1
#   - conda-forge/osx-64::pango==1.42.4=haa940fe_4
#   - conda-forge/noarch::pygments==2.6.1=py_0
#   - conda-forge/noarch::tqdm==4.46.0=pyh9f0ad1d_0
#   - conda-forge/osx-64::r-purrr==0.3.4=r36h17f1fa6_1
#   - conda-forge/noarch::r-r2d3==0.2.3=r36h6115d3f_1002
#   - conda-forge/osx-64::notebook==6.0.3=py37_0
#   - conda-forge/noarch::r-magrittr==1.5=r36h6115d3f_1003
#   - conda-forge/noarch::r-forcats==0.5.0=r36h6115d3f_1
#   - conda-forge/noarch::r-shiny==1.5.0=r36h6115d3f_0
#   - conda-forge/osx-64::chardet==3.0.4=py37hc8dfbb8_1006
#   - conda-forge/noarch::markdown==3.2.1=py_0
#   - conda-forge/osx-64::r-readxl==1.3.1=r36hee97c7f_4
#   - conda-forge/noarch::r-knitr==1.29=r36h6115d3f_0
#   - conda-forge/osx-64::kiwisolver==1.2.0=py37ha1cc60f_0
# ...

# %% [markdown]
# ## Add Virutal Environment to Jupyter Notbeook/Lab

# %%
# !pip install --user ipykernel

# %%
# !python -m ipykernel install --user --name=Intro-CA-Data-Collection

# %% [markdown]
# ## Remove/Delete Virtual Environment

# %%
# !conda env remove --name Intro-CA-Data-Collection

# %% [markdown]
# ## Remove Virtual Environment from Jupyter Notebook/Lab

# %%
# !jupyter kernelspec uninstall Intro-CA-Data-Collection

# %% [markdown]
# ## Check Which Environments Are Available

# %%
# !conda info --envs

# %% [markdown]
# ## Switch Back to Default (base) Environment

# %%
# !conda activate
